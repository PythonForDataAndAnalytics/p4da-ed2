# %% [markdown]
# Python for Data & Analytics - 2nd Edition<br>
# Chapter 17, section 3
#
# *** requires datafiles: measures2.csv, USIX.csv

# %%
import pandas as pd
measures = pd.read_csv('measures2.csv', index_col='#')
measures.head()
# Out:
#    measure
# #
# 1    10.11
# 2     9.85
# 3    10.09
# 4    10.03
# 5    10.51

# %%
measures.plot()
# Out:
# <Axes: xlabel='#'>

# %%
measures['measure'].rolling(10).mean().head(12)
# Out:
# #
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10    10.131
# 11    10.129
# 12    10.118
# Name: measure, dtype: float64

# %%
measures['ten'] = 10
measures['ten'].plot()
measures['measure'].rolling(10).mean().plot()
# Out:
# <Axes: xlabel='#'>

# %%
usix = pd.read_csv('USIX.csv', index_col='Date', parse_dates=True)
usix.head()
# Out:
#               Open    High     Low   Close  AdjustedClose     Volume
# Date
# 2017-01-03  450.08  451.66  447.76  450.48        412.295  182733000
# 2017-01-04  451.24  453.50  451.22  453.16        414.748  157488800
# 2017-01-05  452.54  453.16  450.96  452.80        414.418  156758000
# 2017-01-06  453.06  455.50  451.80  454.42        415.901  143119800
# 2017-01-09  453.82  454.14  452.84  452.92        414.528   93879400

# %%
usix = usix[['AdjustedClose']].copy()
usix['Return'] = usix['AdjustedClose'].pct_change()
usix.head()
# Out:
#             AdjustedClose    Return
# Date
# 2017-01-03        412.295       NaN
# 2017-01-04        414.748  0.005950
# 2017-01-05        414.418 -0.000796
# 2017-01-06        415.901  0.003579
# 2017-01-09        414.528 -0.003301

# %%
usix['Return'].rolling(20).std().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Code from: Python for Data & Analytics, (c) 2025 Rose River Software, LLC
